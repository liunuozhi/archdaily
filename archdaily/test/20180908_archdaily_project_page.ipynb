# %%
import requests
import re
from bs4 import BeautifulSoup
from pprint import pprint

# %%
URL = 'https://www.archdaily.com/71/wall-house-far-frohnrojas'

# %%
def __page_content(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'lxml')
    return soup

def __parse_project_data(soup):
    data = {}
    data['name'] = soup.body.h1.text.strip()
    data['article'] = [ p.text.strip() for p in soup.body.article.find_all('p')]
    
    # project info
    info = soup.find_all('li', attrs={'class': 'afd-char-item'})
    data['info'] = [{x.h3.text.strip():x.div.text.strip()} for x in info]
    
    return data

def project_page(url):
    soup = __page_content(url)
    data = __parse_project_data(soup)
    return data

# %%
data = project_page(URL)
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# D:\Users\ronn\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# D:\Users\ronn\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# D:\Users\ronn\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1537                     if errno != 0:
# -> 1538                         raise SysCallError(errno, errorcode.get(errno))
#    1539                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (10053, 'WSAECONNABORTED')
#
# ...

# %%
pprint(data)
# Out:
# {'article': ['+ 34',
#              '',
#              '',
#              'Text description provided by the architects. Wall house '
#              'innovates on house design, through a sustainable soft skin. This '
#              'house was awarded the 2007 AR Emerging Awards and selected as '
#              'one of the 2008 Record Houses by Architectural Record.',
#              '',
#              'With a limited budget, our office was asked to design a '
#              'residence for a retired couple in one of the suburban areas that '
#              'stretch out from the center of Santiago de Chile along the '
#              'Pan-American Highway. We were immediately curious about the '
#              "ambiguous nature of the couple's purchased lot: while "
#              'technically being part of a suburban subdivision, the '
#              'development actually projected a highly rural image through its '
# ...

# %% [markdown]
# # project name
# soup.body.h1.text.strip()
#
# # article content
# article = [ p.text.strip() for p in soup.body.article.find_all('p')]
# pprint(article)
#
# # project info
# info = soup.find_all('li', attrs={'class': 'afd-char-item'})
# info = [{x.h3.text.strip():x.div.text.strip()} for x in info]
#
# pprint(info)
